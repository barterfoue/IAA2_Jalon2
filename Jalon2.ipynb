# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
DATASET_FILE = "drive/MyDrive/processed_dataset.csv"
df = pd.read_csv(DATASET_FILE)

# %%
# Extracting negative reviews from dataset, her we take 1 and 2 stars reviews
one_star_df = df.loc[df['stars'] == 1]
two_stars_df = df.loc[df['stars'] == 2]
negative_df = one_star_df.append(two_stars_df, ignore_index = True)

negative_df[4998:5002] # checking for the merging at the junction of the dataframes
# Out:
#                                                    text  ...                                         clean text
# 4998  Awful. Awful. Awful. Cold chicken, semi-stale ...  ...  awful awful awful cold chicken semi stale chip...
# 4999  Even if this pizza is the best thing I've ever...  ...  even pizza best thing ever taste not_order ord...
# 5000  As a Northeastern student, I was excited when ...  ...  northeastern student excite place open last ye...
# 5001  So I had to knock my review down a couple of s...  ...  knock review couple star consistency important...
#
# [4 rows x 4 columns]

# %%
# negative_df[4998:5002] # checking for the merging at the junction of the dataframes

# %%
vectorizer = TfidfVectorizer(max_df= 0.8 , min_df= 0.01)
X = vectorizer.fit_transform(negative_df['clean text'])

BOW = pd.DataFrame(data=X.toarray(), columns=vectorizer.get_feature_names_out())

# %%
def display_topics(model, feature_names, num_top_words, topic_names=None):
    topic_tokens = []
    for ix, topic in enumerate(model.components_):
        #print topic, topic number, and top words
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)

        else:
            print("\nTopic: '",topic_names[ix],"'")
        print(", ".join([feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]))
        topic_tokens.append(", ".join([feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]))
    return topic_tokens

# %%
from sklearn.decomposition import NMF

number_of_topics = 15
nmf_model = NMF(number_of_topics)

doc_topic = nmf_model.fit_transform(BOW)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,

# %%
topic_tokens = display_topics(nmf_model, vectorizer.get_feature_names(), 10)

# %%
doc_topic_df = pd.DataFrame(doc_topic)
top_reviews = []

for i in range(number_of_topics):
  top_reviews.append(negative_df['text'][doc_topic_df[i].nlargest(3).index])

# %%
top_review_1, top_review_2, top_review_3 = [], [], []

for i in range(len(top_reviews)):
  top_review_1.append(top_reviews[i].iloc[0])
  top_review_2.append(top_reviews[i].iloc[1])
  top_review_3.append(top_reviews[i].iloc[2])

# %%
topic_df = pd.DataFrame()
topic_df["topics"] = topic_tokens
topic_df["top_review_1"] = top_review_1
topic_df["top_review_2"] = top_review_2
topic_df["top_review_3"] = top_review_3

# %%
topic_df
# Out:
#                                                topics  ...                                       top_review_3
# 0   order, take, delivery, call, wrong, get, hour,...  ...  Normally, I don't write off restaurants based ...
# 1   good, price, restaurant, menu, small, portion,...  ...  For the price comparable to Blu ill, NY we had...
# 2   pizza, crust, cheese, slice, topping, delivery...  ...  Worst Dominos pizza experience I have ever had...
# 3   place, really, go, get, good, people, try, wou...  ...  This place is just okay.  I've never had any f...
# 4   food, cold, quality, back, mediocre, eat, chin...  ...  Go for the drinks at the bar.  The food is med...
# 5   wait, minute, table, us, seat, come, hour, 15,...  ...  DO NOT GO HERE - THE WAITS ARE 5 TIMES LONGER ...
# 6   burger, fry, bun, well, onion, cheese, medium,...  ...  It was an unfortunately unpleasant experience....
# 7   service, bad, customer, ever, slow, horrible, ...  ...  I just went there tonight to have a nice dinne...
# 8   chicken, rice, fry, sauce, wing, dry, piece, s...  ...  Ordered chicken shawarma but guess what's insi...
# 9   bar, drink, beer, bartender, night, friend, go...  ...  I stopped in for a drink at the bar. The barte...
# 10  time, last, go, first, location, every, second...  ...  Second time I got food poisoning from this pla...
# 11  like, taste, look, sauce, soup, flavor, noodle...  ...  I really tried to like this place, but I can't...
# 12  sandwich, cheese, salad, bread, get, lettuce, ...  ...  Stopped here today for lunch after having read...
# 13  sushi, roll, fish, rice, salmon, soup, quality...  ...  Was really looking forward to enjoying some su...
# 14  say, us, ask, back, tell, would, manager, go, ...  ...  There was a bug in my salad tonight. I know it...
#
# [15 rows x 4 columns]

# %%
topic = {'topic1':'ACCUEIL ET SERVICE',
         'topic2':'NOURRITURE ASIATQUE MAUVAISE ',
         'topic3':"TEMPS D'ATTENTE ET PIZZA FROIDE OU TROP CUITE",
         'topic4':'MAUVAISE EXPERIENCE AVEC LE PESONNEL ', 
         'topic5':'PROBLEME BURGER (ERREUR COMMANDE, PRIX ELEVE, ETC)', 
         'topic6':"TEMPS D'ATTENTE TROP LONG", 
         'topic7':'PROBLEME QUALITE BURGER', 
         'topic8':'TRES MAUVAIS SERVICE CLIENT', 
         'topic9':'PROBLEME DE POULET', 
         'topic10':'BAR MAUVAIS EXPEIENCE AVEC LE PERSONNEL', 
         'topic11':'CLIENT DECU, NE REVIENDRA PAS', 
         'topic12':'NOURRITURE JAPONNAISE DECEVANTE', 
         'topic13':'MAUVAIS SANDWICH',
         'topic14':'EXPERIENCE MEDIOCRE, PRIX LEGEREMENT TROP ELEVES', 
         'topic15':'PROBLEME DANS LA COMMANDE' }

# %%
topic

# %%
pickle.dump(vectorizer, open('drive/MyDrive/vectoriseur', 'wb'))
pickle.dump(nmf_model, open('drive/MyDrive/model', 'wb'))
